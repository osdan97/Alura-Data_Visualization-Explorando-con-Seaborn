# %% [markdown]
# <a href="https://colab.research.google.com/github/osdan97/Alura-Data_Visualization-Explorando-con-Seaborn/blob/main/Aula_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importando base de datos

# %%
import pandas as pd

# %%
pd.read_csv('credit_card.csv')
# Out:
#       LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE  \
# 0          6022              Yes       2.University  Married   24
# 1         36132              Yes       2.University   Single   26
# 2         27099              Yes       2.University   Single   34
# 3         15055              Yes       2.University  Married   37
# 4        150550               No  3.Graduate School   Single   29
# ...         ...              ...                ...      ...  ...
# 1495      54198              Yes  3.Graduate School   Single   27
# 1496      45165               No       2.University  Married   55
# 1497      78286               No  3.Graduate School   Single   34
# 1498       6022               No       2.University  Married   44
# 1499     183671               No  3.Graduate School   Single   31
#
#          BILL_AMT     PAY_AMT  DEFAULT
# 0        934.0122      0.0000        1
# 1        519.3975      0.0000        1
# 2       4223.5297    457.0698        0
# ...

# %%
datos = pd.read_csv('credit_card.csv')

# %%
datos.head()
# Out:
#    LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE     BILL_AMT  \
# 0       6022              Yes       2.University  Married   24     934.0122
# 1      36132              Yes       2.University   Single   26     519.3975
# 2      27099              Yes       2.University   Single   34    4223.5297
# 3      15055              Yes       2.University  Married   37   14522.9563
# 4     150550               No  3.Graduate School   Single   29  124060.1253
#
#       PAY_AMT  DEFAULT
# 0      0.0000        1
# 1      0.0000        1
# 2    457.0698        0
# 3    602.2000        0
# 4  16560.5000        0

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LIMIT_BAL         1500 non-null   int64
#  1   CHECKING_ACCOUNT  1500 non-null   object
#  2   EDUCATION         1500 non-null   object
#  3   MARRIAGE          1500 non-null   object
#  4   AGE               1500 non-null   int64
#  5   BILL_AMT          1500 non-null   float64
#  6   PAY_AMT           1500 non-null   float64
#  7   DEFAULT           1500 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 93.9+ KB

# %% [markdown]
# # Traduciendo variables

# %%
datos.columns
# Out:
# Index(['LIMIT_BAL', 'CHECKING_ACCOUNT', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'BILL_AMT', 'PAY_AMT', 'DEFAULT'],
#       dtype='object')

# %%
dic_columnas = {
    'LIMIT_BAL' : 'limite', 
    'CHECKING_ACCOUNT' : 'cuenta_corriente', 
    'EDUCATION' : 'escolaridad', 
    'MARRIAGE' : 'estado_civil', 
    'AGE' : 'edad',
    'BILL_AMT' : 'valor_factura', 
    'PAY_AMT' : 'valor_pago', 
    'DEFAULT' : 'moroso'
}

# %%
tarjetas = datos.rename(columns = dic_columnas)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.cuenta_corriente.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
dic_cuenta = {
    'Yes' : 'Si', 
    'No' : 'No'
}

# %%
tarjetas.cuenta_corriente.map(dic_cuenta)
# Out:
# 0       Si
# 1       Si
# 2       Si
# 3       Si
# 4       No
#         ..
# 1495    Si
# 1496    No
# 1497    No
# 1498    No
# 1499    No
# Name: cuenta_corriente, Length: 1500, dtype: object

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.cuenta_corriente = tarjetas.cuenta_corriente.map(dic_cuenta)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022               Si       2.University      Married    24
# 1   36132               Si       2.University       Single    26
# 2   27099               Si       2.University       Single    34
# 3   15055               Si       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.escolaridad.unique()
# Out:
# array(['2.University', '3.Graduate School', '1.High School'], dtype=object)

# %%
dic_escolaridad = {
    '2.University' : '2.Universidad', 
    '3.Graduate School' : '3.Pos-graduación', 
    '1.High School' : '1.Colegio'
}

# %%
tarjetas.escolaridad = tarjetas.escolaridad.map(dic_escolaridad)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad      Married    24
# 1   36132               Si     2.Universidad       Single    26
# 2   27099               Si     2.Universidad       Single    34
# 3   15055               Si     2.Universidad      Married    37
# 4  150550               No  3.Pos-graduación       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.estado_civil.unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
dic_estado_civil = {
    'Married' : 'Casado/a', 
    'Single' : 'Soltero/a'
}

# %%
tarjetas.estado_civil = tarjetas.estado_civil.map(dic_estado_civil)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
# !pip install seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# #Importando Seaborn

# %%
import seaborn as sb

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.12.2
# Summary: Statistical data visualization
# Home-page:
# Author:
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License:
# Location: /usr/local/lib/python3.9/dist-packages
# Requires: matplotlib, numpy, pandas
# Required-by: missingno, pandas-profiling

# %%
#las opciones que tenemos son: (darkgrid, whitegrid, dark, white, ticks)
sb.set_style('darkgrid')

# %%
#plasma,magma,inferno,vidiris,cividis
graf=sb.displot(data=tarjetas,x='edad',hue='escolaridad',palette='Dark2');

# %%
tarjetas['Porcentaje_uso_credito']=(tarjetas['valor_factura']/tarjetas['limite']).round(2)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso  Porcentaje_uso_credito
# 0       934.0122      0.0000       1                    0.16
# 1       519.3975      0.0000       1                    0.01
# 2      4223.5297    457.0698       0                    0.16
# 3     14522.9563    602.2000       0                    0.96
# 4    124060.1253  16560.5000       0                    0.82

# %%
sb.displot(data=tarjetas,x='Porcentaje_uso_credito');

# %% [markdown]
# existen pocas personas que hacen uso del limite de su credito

# %%
sb.countplot(data=tarjetas,x='cuenta_corriente');

# %%
sb.countplot(data=tarjetas,x='cuenta_corriente',hue='moroso',palette='coolwarm');

# %%
sb.catplot(x='estado_civil',y='limite',data=tarjetas,hue='moroso',dodge=True);

# %%
sb.swarmplot(data=tarjetas,y='Porcentaje_uso_credito',x='escolaridad',dodge=True);
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 9.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 22.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 14.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 27.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#Graficos con mediana
sb.boxplot(data=tarjetas,x='escolaridad',y='Porcentaje_uso_credito',hue='moroso',palette='bone');

# %%
sb.violinplot(data=tarjetas,x='escolaridad',y='Porcentaje_uso_credito',hue='moroso');

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso  Porcentaje_uso_credito
# 0       934.0122      0.0000       1                    0.16
# 1       519.3975      0.0000       1                    0.01
# 2      4223.5297    457.0698       0                    0.16
# 3     14522.9563    602.2000       0                    0.96
# 4    124060.1253  16560.5000       0                    0.82

# %%
import pandas as pd
bins=[20,30,40,50,100]
nombres=['20-30','30-40','40-50','50+']
tarjetas['rango_edad']=pd.cut(tarjetas['edad'],bins=bins,labels=nombres)

# %%
sb.boxplot(x='rango_edad',y='limite',data=tarjetas);

# %% [markdown]
# #Variables numericas

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso  Porcentaje_uso_credito rango_edad
# 0       934.0122      0.0000       1                    0.16      20-30
# 1       519.3975      0.0000       1                    0.01      20-30
# 2      4223.5297    457.0698       0                    0.16      30-40
# 3     14522.9563    602.2000       0                    0.96      30-40
# 4    124060.1253  16560.5000       0                    0.82      20-30

# %%
sb.displot(data=tarjetas,x='limite',col='escolaridad',kind='kde',hue='rango_edad');

# %%
sb.scatterplot(data=tarjetas,x='Porcentaje_uso_credito',y='valor_factura',hue='cuenta_corriente');

# %%
sb.lmplot(data=tarjetas,x='Porcentaje_uso_credito',y='valor_factura',col='moroso');

# %%
from scipy.stats import ranksums

# %% [markdown]
# H<sup>null<sup>
# La distibucion grafica de los morosos y no morosos es la misma

# %% [markdown]
# H<sup>alt<sup>

# %% [markdown]
# La distribucion grafica de los morosos y no morosos no es la misma

# %%
morosos=tarjetas.query('moroso==1').valor_factura
morosos

# %%
no_morosos=tarjetas.query('moroso==0').valor_factura
no_morosos

# %%
resultado=ranksums(morosos,no_morosos)
print('El pvalue de la hipotesis es {}'.format(resultado.pvalue))
# Out:
# El pvalue de la hipotesis es 0.010391243081223555

# %% [markdown]
# #JointPlot

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso  Porcentaje_uso_credito rango_edad
# 0       934.0122      0.0000       1                    0.16      20-30
# 1       519.3975      0.0000       1                    0.01      20-30
# 2      4223.5297    457.0698       0                    0.16      30-40
# 3     14522.9563    602.2000       0                    0.96      30-40
# 4    124060.1253  16560.5000       0                    0.82      20-30

# %%
sb.jointplot(data=tarjetas,x='edad',y='limite',kind='hex');

# %%
sb.jointplot(x='edad', y='Porcentaje_uso_credito', data=tarjetas, kind='scatter');

# %% [markdown]
# #PairPlot

# %%
tarjetas.describe()
# Out:
#               limite         edad  valor_factura    valor_pago       moroso  \
# count    1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean    51221.943333    35.212667   15459.869900   1984.869266     0.078000
# std     39424.407462     9.274955   20722.582831   5296.771686     0.268261
# min      3011.000000    21.000000      27.701200      0.000000     0.000000
# 25%     18066.000000    28.000000    2035.586550    407.011925     0.000000
# 50%     42154.000000    33.500000    7701.385250    759.374200     0.000000
# 75%     72264.000000    41.000000   20671.568850   1705.279850     0.000000
# max    210770.000000    75.000000  141792.506500  97022.850800     1.000000
#
#        Porcentaje_uso_credito
# count             1500.000000
# mean                 0.388193
# std                  0.341984
# min                  0.000000
# 25%                  0.050000
# 50%                  0.310000
# 75%                  0.700000
# max                  1.000000

# %%
sb.pairplot(data=tarjetas,hue='escolaridad',palette='cividis');
